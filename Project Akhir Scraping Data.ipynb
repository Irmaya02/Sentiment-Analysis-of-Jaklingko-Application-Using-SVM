# %% [markdown]
# ## Scraping data

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#Get Jaklingko
from google_play_scraper import Sort, reviews_all


us_reviews = reviews_all(
    'com.jaklingkoindonesia.app',
    sleep_milliseconds=0, # defaults to 0
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df = pd.DataFrame(np.array(us_reviews),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.head()
# Out:
#                                reviewId             userName  \
# 0  539f3ccd-162c-486a-ac4c-80121ecd1c35  Iqbal Permana Putra
# 1  e49bf61e-dfe9-4da0-b84d-1d2f70faab75            Sahabudin
# 2  fc88b145-8bd9-4aa4-ac44-df43fcc5af72       Jefri Manurung
# 3  b5b9e3a6-8f72-4bcb-8d41-bedb75b7b24b                 lexa
# 4  c8afc111-8952-4bb8-adee-954f303e404a              Reza MM
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Interface buruk menyulitkan pengguna. Beli tik...      1              0
# 1  Tolong check out nya jangan harus sesuai tujua...      1              0
# ...

# %%
len(df.index) #count the number of data we got
# Out:
# 326

# %%
df[['userName', 'score','at', 'content']]
# Out:
#                  userName  score                  at  \
# 0     Iqbal Permana Putra      1 2023-11-16 00:24:27
# 1               Sahabudin      1 2023-11-13 12:29:34
# 2          Jefri Manurung      5 2023-11-03 13:04:44
# 3                    lexa      1 2023-11-02 00:52:46
# 4                 Reza MM      1 2023-10-27 14:20:38
# ..                    ...    ...                 ...
# 321             Rudatz FM      5 2022-01-03 06:54:01
# 322           Adhit Arham      5 2022-01-03 05:31:40
# 323          Dedy Suryadi      5 2022-01-03 04:38:31
# 324  Mohammad Dwijanuarto      5 2022-01-03 04:35:14
# 325         Bayu Anindito      5 2022-01-03 04:34:24
#
#                                                content
# 0    Interface buruk menyulitkan pengguna. Beli tik...
# 1    Tolong check out nya jangan harus sesuai tujua...
# 2             fast response when handling my complaint
# 3    tiket udah di beli tapi tak bisa digunakan. re...
# ...

# %%
clean_df = df[['userName', 'score','at', 'content']]
clean_df.head()
# Out:
#               userName  score                  at  \
# 0  Iqbal Permana Putra      1 2023-11-16 00:24:27
# 1            Sahabudin      1 2023-11-13 12:29:34
# 2       Jefri Manurung      5 2023-11-03 13:04:44
# 3                 lexa      1 2023-11-02 00:52:46
# 4              Reza MM      1 2023-10-27 14:20:38
#
#                                              content
# 0  Interface buruk menyulitkan pengguna. Beli tik...
# 1  Tolong check out nya jangan harus sesuai tujua...
# 2           fast response when handling my complaint
# 3  tiket udah di beli tapi tak bisa digunakan. re...
# 4  Buruk bgt, jangan coba2. Mending beli kartu em...

# %%
clean_df.to_csv("Clean Dataset Jaklingko.csv", index = False)
